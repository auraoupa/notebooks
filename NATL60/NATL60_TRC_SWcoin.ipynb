# %%
# import modules
import xarray as xr
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import numpy.ma as ma
import numpy as np
import netCDF4 as nc4
from scipy.io import netcdf
# %matplotlib inline
# Out:
# /home/albert/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
fdir = "/home/albert/Data/NATL60/NATL60-CJM165-S/1d/2012/"
TRCfile = fdir + 'NATL60-CJM165_y2012m11d07.1d_ptrcT_coinSW.nc'
Tfile = fdir + 'NATL60-CJM165_y2012m11d07.1d_gridT_coinSW.nc'
Vfile = fdir + 'NATL60-CJM165_y2012m11d07.1d_gridV_coinSW.nc'
Wfile = fdir + 'NATL60-CJM165_y2012m11d07.1d_gridW_coinSW.nc'

# %%
TRC = xr.open_dataset(TRCfile)['TRC'][0]
T = xr.open_dataset(Tfile)['votemper'][0]
V = xr.open_dataset(Vfile)['vomecrty'][0]
W = xr.open_dataset(Wfile)['vovecrtz'][0]

navlon = xr.open_dataset(TRCfile)['nav_lon']
navlat = xr.open_dataset(TRCfile)['nav_lat']

# %%
TRC.shape
navlon.shape
np.max(ma.masked_invalid(TRC[0,0:75,100:120]))
# Out:
# 1.7163227796554565

# %% [markdown]
# # Champs de surface x=100:120 y=0:75 z=0

# %%
plt.figure(figsize=(20,15))
plt.suptitle('Champs de surface (x,y) x=100:120 y=0:75 z=0 y2012m11d07',fontsize=16)
plt.subplot(2,2,1)
plt.pcolor(ma.masked_invalid(TRC[0,0:75,100:120]),vmin=0,vmax=1,cmap='jet')
plt.vlines(8.5,0,75)
plt.hlines(30,0,20)
plt.autoscale(tight=True)
plt.colorbar(orientation='horizontal')
plt.title('TRC ')
plt.subplot(2,2,2)
plt.pcolor(ma.masked_invalid(T[0,0:75,100:120]),vmin=27,vmax=27.6,cmap='jet')
plt.vlines(8.5,0,75)
plt.hlines(30,0,20)
plt.autoscale(tight=True)
plt.colorbar(orientation='horizontal')
plt.title('Temp in degC')
plt.subplot(2,2,3)
plt.pcolor(ma.masked_invalid(V[0,0:75,100:120]),vmin=0.8,vmax=1.2,cmap='jet')
plt.vlines(8.5,0,75)
plt.hlines(30,0,20)
plt.autoscale(tight=True)
plt.colorbar(orientation='horizontal')
plt.title('V in m/s')
plt.subplot(2,2,4)
plt.pcolor(86400*ma.masked_invalid(W[0,0:75,100:120]),vmin=-0.02,vmax=0.02,cmap='seismic')
plt.vlines(8.5,0,75)
plt.hlines(30,0,20)
plt.autoscale(tight=True)
plt.colorbar(orientation='horizontal')
plt.title('W in m/day')

plt.savefig("/home/albert/Data/NATL60/NATL60-CJM165-PLOTS/cartesxy_TRC_temp_v_w_y2012m11d07.png")

# %%
np.max(ma.masked_invalid(TRC[0,0:75,100:120]))
# Out:
# 1.7163227796554565

# %% [markdown]
# # Sections (x,z) x=100:120 y=2 z=0:50

# %%
plt.figure(figsize=(20,15))
plt.suptitle('Sections (x,z) x=100:120 y=3 z=0:50 y2012m11d07',fontsize=16)
plt.subplot(2,2,1)
plt.pcolor(ma.masked_invalid(TRC[0:50,2,100:120]),vmin=0,vmax=1,cmap='jet')
plt.hlines(27.5,0,20)
plt.gca().invert_yaxis()
plt.autoscale(tight=True)
plt.colorbar(orientation='horizontal')
plt.title('TRC')
plt.subplot(2,2,2)
plt.pcolor(ma.masked_invalid(T[0:50,2,100:120]),vmin=27,vmax=27.6,cmap='jet')
plt.hlines(27.5,0,20)
plt.gca().invert_yaxis()
plt.autoscale(tight=True)
plt.colorbar(orientation='horizontal')
plt.title('Temp in degC')
plt.subplot(2,2,3)
plt.pcolor(ma.masked_invalid(V[0:50,2,100:120]),vmin=0.8,vmax=1.2,cmap='jet')
plt.hlines(27.5,0,20)
plt.gca().invert_yaxis()
plt.autoscale(tight=True)
plt.colorbar(orientation='horizontal')
plt.title('V in m/s')
plt.subplot(2,2,4)
plt.pcolor(86400*ma.masked_invalid(W[0:50,2,100:120]),vmin=0,vmax=1000,cmap='jet')
plt.hlines(27.5,0,20)
plt.gca().invert_yaxis()
plt.autoscale(tight=True)
plt.colorbar(orientation='horizontal')
plt.title('W in m/day')

plt.savefig("/home/albert/Data/NATL60/NATL60-CJM165-PLOTS/sectionxz_TRC_temp_v_w_y2012m11d07.png")

# %%
np.max(86400*ma.masked_invalid(W[0:50,2,100:120]))
# Out:
# 1706.3442349433899

# %% [markdown]
# # Sections (y,z) x=107 y=0:75 z=0:50

# %%
plt.figure(figsize=(20,15))
plt.suptitle('Sections (y,z) x=108 y=0:75 z=0:50 y2012m11d07',fontsize=16)
plt.subplot(2,2,1)
plt.pcolor(ma.masked_invalid(TRC[0:50,0:75,107]),vmin=0,vmax=10,cmap='jet')
plt.hlines(20.5,0,75)
plt.gca().invert_yaxis()
plt.autoscale(tight=True)
plt.colorbar(orientation='horizontal')
plt.title('TRC ')
plt.subplot(2,2,2)
plt.pcolor(ma.masked_invalid(T[0:50,0:75,107]),vmin=27,vmax=27.6,cmap='jet')
plt.hlines(20.5,0,75)
plt.gca().invert_yaxis()
plt.autoscale(tight=True)
plt.colorbar(orientation='horizontal')
plt.title('Temp in degC')
plt.subplot(2,2,3)
plt.pcolor(ma.masked_invalid(V[0:50,0:75,107]),vmin=0.8,vmax=1.2,cmap='jet')
plt.hlines(20.5,0,75)
plt.gca().invert_yaxis()
plt.autoscale(tight=True)
plt.colorbar(orientation='horizontal')
plt.title('V in m/s')
plt.subplot(2,2,4)
plt.pcolor(86400*ma.masked_invalid(W[0:50,0:75,107]),vmin=-100,vmax=100,cmap='seismic')
plt.hlines(20.5,0,75)
plt.gca().invert_yaxis()
plt.autoscale(tight=True)
plt.colorbar(orientation='horizontal')
plt.title('W in m/day')

plt.savefig("/home/albert/Data/NATL60/NATL60-CJM165-PLOTS/sectionyz_TRC_temp_v_w_y2012m11d07.png")

# %%
plt.figure(figsize=(20,15))
plt.suptitle('Profils selon x en y=30 z=0 y2012m11d07',fontsize=16)
plt.subplot(2,2,1)
plt.plot(ma.masked_invalid(TRC[0,30,100:120]),'k-+')
plt.title('TRC ')
plt.subplot(2,2,2)
plt.plot(ma.masked_invalid(T[0,30,100:120]),'b-+')
plt.title('Temp in degC')
plt.subplot(2,2,3)
plt.plot(ma.masked_invalid(V[0,30,100:120]),'g-+')
plt.title('V in m/s')
plt.subplot(2,2,4)
plt.plot(86400*ma.masked_invalid(W[0,30,100:120]),'r-+')
plt.title('W in m/day')


plt.savefig("/home/albert/Data/NATL60/NATL60-CJM165-PLOTS/profilsx_y30_z0_TRC_temp_v_w_y2012m11d07.png")

# %%
plt.figure(figsize=(20,15))
plt.suptitle('Profils selon y en x=108 z=0 y2012m11d07',fontsize=16)
plt.subplot(2,2,1)
plt.plot(ma.masked_invalid(TRC[0,0:75,108]),'k-+')
plt.title('TRC ')
plt.subplot(2,2,2)
plt.plot(ma.masked_invalid(T[0,0:75,108]),'b-+')
plt.title('Temp in degC')
plt.subplot(2,2,3)
plt.plot(ma.masked_invalid(V[0,0:75,108]),'g-+')
plt.title('V in m/s')
plt.subplot(2,2,4)
plt.plot(86400*ma.masked_invalid(W[0,0:75,108]),'r-+')
plt.title('W in m/day')


plt.savefig("/home/albert/Data/NATL60/NATL60-CJM165-PLOTS/profilsy_x108_z0_TRC_temp_v_w_y2012m11d07.png")

# %%
plt.figure(figsize=(20,15))
plt.suptitle('Profils selon x en y=3 z=27 y2012m11d07',fontsize=16)
plt.subplot(2,2,1)
plt.plot(ma.masked_invalid(TRC[27,2,100:120]),'k-+')
plt.title('TRC ')
plt.subplot(2,2,2)
plt.plot(ma.masked_invalid(T[27,2,100:120]),'b-+')
plt.title('Temp in degC')
plt.subplot(2,2,3)
plt.plot(ma.masked_invalid(V[27,2,100:120]),'g-+')
plt.title('V in m/s')
plt.subplot(2,2,4)
plt.plot(86400*ma.masked_invalid(W[27,2,100:120]),'r-+')
plt.title('W in m/day')


plt.savefig("/home/albert/Data/NATL60/NATL60-CJM165-PLOTS/profilsx_y3_z27_TRC_temp_v_w_y2012m11d07.png")

# %%
plt.figure(figsize=(20,15))
plt.suptitle('Profils selon y en x=108 z=20 y2012m11d07',fontsize=16)
plt.subplot(2,2,1)
plt.plot(ma.masked_invalid(TRC[20,0:75,107]),'k-+')
plt.title('TRC ')
plt.subplot(2,2,2)
plt.plot(ma.masked_invalid(T[20,0:75,107]),'b-+')
plt.title('Temp in degC')
plt.subplot(2,2,3)
plt.plot(ma.masked_invalid(V[20,0:75,107]),'g-+')
plt.title('V in m/s')
plt.subplot(2,2,4)
plt.plot(86400*ma.masked_invalid(W[20,0:75,107]),'r-+')
plt.title('W in m/day')


plt.savefig("/home/albert/Data/NATL60/NATL60-CJM165-PLOTS/profilsy_x108_z20_TRC_temp_v_w_y2012m11d07.png")
