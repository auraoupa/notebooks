# %%
import sys
import numpy as np
import numpy.ma as ma
import xarray as xr
import matplotlib.pyplot as plt
sys.path.insert(0,'/home/albert7a/lib/python/cartopy/lib/cartopy')
import matplotlib.ticker as mticker
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.feature as cfeature
import cmocean
import datetime
import matplotlib.dates as mdates
sys.path.insert(0,'/home/albert7a/lib/python/pyspec/pyspec')
from pyspec import spectrum as spec
import scipy.signal as signal

# %matplotlib inline

# %%
dir60='/media/extra/DATA/IBI/IBI60-CJM165-S/'
dir12='/media/extra/DATA/IBI/IBI12.L75-MAA13-S/'

UKfiles60='ptUK-IBI60-CJM165_y????m??d??.1h_gridT.nc'
UKtfiles60=dir60+UKfiles60
UKds60 = xr.open_mfdataset(UKtfiles60,concat_dim='time_counter')

UKfiles12='ptUK-IBI12.L75-MAA13_y????m??d??.1h_SSH.nc'
UKtfiles12=dir12+UKfiles12
UKds12 = xr.open_mfdataset(UKtfiles12,concat_dim='time_counter')

IRLfiles60='ptIRL-IBI60-CJM165_y????m??d??.1h_gridT.nc'
IRLtfiles60=dir60+IRLfiles60
IRLds60 = xr.open_mfdataset(IRLtfiles60,concat_dim='time_counter')

IRLfiles12='ptIRL-IBI12.L75-MAA13_y????m??d??.1h_SSH.nc'
IRLtfiles12=dir12+IRLfiles12
IRLds12 = xr.open_mfdataset(IRLtfiles12,concat_dim='time_counter')

NORfiles60='ptNOR-IBI60-CJM165_y????m??d??.1h_gridT.nc'
NORtfiles60=dir60+NORfiles60
NORds60 = xr.open_mfdataset(NORtfiles60,concat_dim='time_counter')

NORfiles12='ptNOR-IBI12.L75-MAA13_y????m??d??.1h_SSH.nc'
NORtfiles12=dir12+NORfiles12
NORds12 = xr.open_mfdataset(NORtfiles12,concat_dim='time_counter')

MEDfiles60='ptMED-IBI60-CJM165_y????m??d??.1h_gridT.nc'
MEDtfiles60=dir60+MEDfiles60
MEDds60 = xr.open_mfdataset(MEDtfiles60,concat_dim='time_counter')

MEDfiles12='ptMED-IBI12.L75-MAA13_y????m??d??.1h_SSH.nc'
MEDtfiles12=dir12+MEDfiles12
MEDds12 = xr.open_mfdataset(MEDtfiles12,concat_dim='time_counter')

# %%
ssh12UK=np.squeeze(UKds12.sossheig)
ssh12NOR=np.squeeze(NORds12.sossheig)
ssh12IRL=np.squeeze(IRLds12.sossheig)
ssh12MED=np.squeeze(MEDds12.sossheig)

ssh60UK=np.squeeze(UKds60.sossheig)
ssh60NOR=np.squeeze(NORds60.sossheig)
ssh60IRL=np.squeeze(IRLds60.sossheig)
ssh60MED=np.squeeze(MEDds60.sossheig)

# %% [markdown]
# # Spectres time series décembre 2012-février 2013, sans la moyenne

# %%
ssh12UK3mois=ssh12UK.sel(time_counter=slice('2012-12-01','2013-02-28'))
ssh12NOR3mois=ssh12NOR.sel(time_counter=slice('2012-12-01','2013-02-28'))
ssh12IRL3mois=ssh12IRL.sel(time_counter=slice('2012-12-01','2013-02-28'))
ssh12MED3mois=ssh12MED.sel(time_counter=slice('2012-12-01','2013-02-28'))

ssh60UK3mois=ssh60UK.sel(time_counter=slice('2012-12-01','2013-02-28'))
ssh60NOR3mois=ssh60NOR.sel(time_counter=slice('2012-12-01','2013-02-28'))
ssh60IRL3mois=ssh60IRL.sel(time_counter=slice('2012-12-01','2013-02-28'))
ssh60MED3mois=ssh60MED.sel(time_counter=slice('2012-12-01','2013-02-28'))

# %%
dssh12UK3mois=ssh12UK3mois-np.mean(ssh12UK3mois)
dssh12NOR3mois=ssh12NOR3mois-np.mean(ssh12NOR3mois)
dssh12IRL3mois=ssh12IRL3mois-np.mean(ssh12IRL3mois)
dssh12MED3mois=ssh12MED3mois-np.mean(ssh12MED3mois)

dssh60UK3mois=ssh60UK3mois-np.mean(ssh60UK3mois)
dssh60NOR3mois=ssh60NOR3mois-np.mean(ssh60NOR3mois)
dssh60IRL3mois=ssh60IRL3mois-np.mean(ssh60IRL3mois)
dssh60MED3mois=ssh60MED3mois-np.mean(ssh60MED3mois)

# %% [markdown]
# ## Comparaison différentes méthodes

# %%
kperio,Pperio=signal.periodogram(dssh12UK3mois.values)

kwelch, Pwelch = signal.welch(dssh12UK3mois.values, fs=1., window='hanning', nperseg=dssh12UK3mois.size, noverlap=False,
                             detrend='constant', scaling='density', axis=-1)

sshpyspec = spec.Spectrum(dssh12UK3mois.copy(),dt=1)

# %%
fig=plt.figure(figsize=(25,5))

ax = fig.add_subplot(111)

plt.loglog(kperio,Pperio,color='b',label="periodogramm")
plt.loglog(kwelch,Pwelch,color='k',label="welch")
plt.loglog(sshpyspec.f,sshpyspec.spec,color='g',label="pyspec")
plt.grid()
plt.title('SSH UK')
plt.legend()
plt.ylim([1e-8,20])
plt.axvline(1/12.,color='k',linestyle='dashed')
plt.text(1/12.-0.003,22,'12h')
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.003,22,'24h')

# %%
fig=plt.figure(figsize=(25,5))

ax = fig.add_subplot(111)

plt.loglog(kperio,Pperio,color='b',label="periodogramm")
plt.loglog(kwelch,Pwelch,color='k',label="welch")
plt.loglog(sshpyspec.f,sshpyspec.spec,color='g',label="pyspec")
plt.grid()
plt.title('SSH UK')
plt.legend()
plt.ylim([1e-8,20])
plt.xlim([1e-2,1e-1])
plt.axvline(1/12.,color='k',linestyle='dashed')
plt.text(1/12.-0.001,22,'12h')
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.001,22,'24h')

# %% [markdown]
# ## tout en periodogramme

# %%
fdssh12UK3mois,Pxxdssh12UK3mois=signal.periodogram(dssh12UK3mois.values)
fdssh60UK3mois,Pxxdssh60UK3mois=signal.periodogram(dssh60UK3mois.values)

fdssh12NOR3mois,Pxxdssh12NOR3mois=signal.periodogram(dssh12NOR3mois.values)
fdssh60NOR3mois,Pxxdssh60NOR3mois=signal.periodogram(dssh60NOR3mois.values)

fdssh12IRL3mois,Pxxdssh12IRL3mois=signal.periodogram(dssh12IRL3mois.values)
fdssh60IRL3mois,Pxxdssh60IRL3mois=signal.periodogram(dssh60IRL3mois.values)

fdssh12MED3mois,Pxxdssh12MED3mois=signal.periodogram(dssh12MED3mois.values)
fdssh60MED3mois,Pxxdssh60MED3mois=signal.periodogram(dssh60MED3mois.values)

# %%
fig=plt.figure(figsize=(20,20))

ax = fig.add_subplot(411)

plt.loglog(fdssh12NOR3mois,Pxxdssh12NOR3mois,color='b',label="NACHOS12")
plt.loglog(fdssh60NOR3mois,Pxxdssh60NOR3mois,color='k',label="NATL60")
plt.ylim([1e-8,20])
plt.axvline(1/12.,color='k',linestyle='dashed')
plt.text(1/12.-0.003,22,'12h')
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.003,22,'24h')
plt.grid()
plt.title('SSH NOR')
plt.legend()

ax = fig.add_subplot(412)

plt.loglog(fdssh12UK3mois,Pxxdssh12UK3mois,color='b',label="NACHOS12")
plt.loglog(fdssh60UK3mois,Pxxdssh60UK3mois,color='k',label="NATL60")
plt.ylim([1e-8,20])
plt.axvline(1/12.,color='k',linestyle='dashed')
plt.text(1/12.-0.003,22,'12h')
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.003,22,'24h')
plt.grid()
plt.title('SSH UK')
plt.legend()

ax = fig.add_subplot(413)

plt.loglog(fdssh12IRL3mois,Pxxdssh12IRL3mois,color='b',label="NACHOS12")
plt.loglog(fdssh60IRL3mois,Pxxdssh60IRL3mois,color='k',label="NATL60")
plt.ylim([1e-8,20])
plt.axvline(1/12.,color='k',linestyle='dashed')
plt.text(1/12.-0.003,22,'12h')
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.003,22,'24h')
plt.grid()
plt.title('SSH IRL')
plt.legend()

ax = fig.add_subplot(414)

plt.loglog(fdssh12MED3mois,Pxxdssh12MED3mois,color='b',label="NACHOS12")
plt.loglog(fdssh60MED3mois,Pxxdssh60MED3mois,color='k',label="NATL60")
plt.ylim([1e-8,20])
plt.axvline(1/12.,color='k',linestyle='dashed')
plt.text(1/12.-0.003,22,'12h')
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.003,22,'24h')
plt.grid()
plt.title('SSH MED')
plt.legend()

# %%
fig=plt.figure(figsize=(20,20))

ax = fig.add_subplot(411)

plt.loglog(fdssh12NOR3mois,Pxxdssh12NOR3mois,color='b',label="NACHOS12")
plt.loglog(fdssh60NOR3mois,Pxxdssh60NOR3mois,color='k',label="NATL60")
plt.ylim([1e-8,20])
plt.xlim([0.01,0.1])
plt.axvline(1/12.,color='k',linestyle='dashed')
plt.text(1/12.-0.001,22,'12h')
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.001,22,'24h')
plt.grid()
plt.title('SSH NOR')
plt.legend()

ax = fig.add_subplot(412)

plt.loglog(fdssh12UK3mois,Pxxdssh12UK3mois,color='b',label="NACHOS12")
plt.loglog(fdssh60UK3mois,Pxxdssh60UK3mois,color='k',label="NATL60")
plt.ylim([1e-8,20])
plt.xlim([0.01,0.1])
plt.axvline(1/12.,color='k',linestyle='dashed')
plt.text(1/12.-0.001,22,'12h')
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.001,22,'24h')
plt.grid()
plt.title('SSH UK')
plt.legend()

ax = fig.add_subplot(413)

plt.loglog(fdssh12IRL3mois,Pxxdssh12IRL3mois,color='b',label="NACHOS12")
plt.loglog(fdssh60IRL3mois,Pxxdssh60IRL3mois,color='k',label="NATL60")
plt.ylim([1e-8,20])
plt.xlim([0.01,0.1])
plt.axvline(1/12.,color='k',linestyle='dashed')
plt.text(1/12.-0.001,22,'12h')
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.001,22,'24h')
plt.grid()
plt.title('SSH IRL')
plt.legend()

ax = fig.add_subplot(414)

plt.loglog(fdssh12MED3mois,Pxxdssh12MED3mois,color='b',label="NACHOS12")
plt.loglog(fdssh60MED3mois,Pxxdssh60MED3mois,color='k',label="NATL60")
plt.ylim([1e-8,20])
plt.xlim([0.01,0.1])
plt.axvline(1/12.,color='k',linestyle='dashed')
plt.text(1/12.-0.001,22,'12h')
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.001,22,'24h')
plt.grid()
plt.title('SSH MED')
plt.legend()

# %%
fig=plt.figure(figsize=(20,20))

ax = fig.add_subplot(411)

plt.loglog(fdssh12NOR3mois,Pxxdssh12NOR3mois,color='b',label="NACHOS12")
plt.loglog(fdssh60NOR3mois,Pxxdssh60NOR3mois,color='k',label="NATL60")
plt.ylim([1e-8,20])
plt.xlim([0.03,0.05])
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.0001,22.5,'24h')
plt.axvline(0.04075,color='k',linestyle='dashed')
plt.text(0.04075-0.0003,22.5,'24.54h')
plt.axvline(0.0398,color='k',linestyle='dashed')
plt.text(0.0398-0.0003,22.5,'25.12h')
plt.grid()
plt.title('SSH NOR')
plt.legend()

ax = fig.add_subplot(412)

plt.loglog(fdssh12UK3mois,Pxxdssh12UK3mois,color='b',label="NACHOS12")
plt.loglog(fdssh60UK3mois,Pxxdssh60UK3mois,color='k',label="NATL60")
plt.ylim([1e-8,20])
plt.xlim([0.03,0.05])
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.0001,22.5,'24h')
plt.axvline(0.04075,color='k',linestyle='dashed')
plt.text(0.04075-0.0003,22.5,'24.54h')
plt.axvline(0.0398,color='k',linestyle='dashed')
plt.text(0.0398-0.0003,22.5,'25.12h')
plt.grid()
plt.title('SSH UK')
plt.legend()

ax = fig.add_subplot(413)

plt.loglog(fdssh12IRL3mois,Pxxdssh12IRL3mois,color='b',label="NACHOS12")
plt.loglog(fdssh60IRL3mois,Pxxdssh60IRL3mois,color='k',label="NATL60")
plt.ylim([1e-8,20])
plt.xlim([0.03,0.05])
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.0001,22.5,'24h')
plt.axvline(0.04075,color='k',linestyle='dashed')
plt.text(0.04075-0.0003,22.5,'24.54h')
plt.axvline(0.0398,color='k',linestyle='dashed')
plt.text(0.0398-0.0003,22.5,'25.12h')
plt.grid()
plt.title('SSH IRL')
plt.legend()

ax = fig.add_subplot(414)

plt.loglog(fdssh12MED3mois,Pxxdssh12MED3mois,color='b',label="NACHOS12")
plt.loglog(fdssh60MED3mois,Pxxdssh60MED3mois,color='k',label="NATL60")
plt.ylim([1e-8,20])
plt.xlim([0.03,0.05])
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.0001,22.5,'24h')
plt.axvline(0.04075,color='k',linestyle='dashed')
plt.text(0.04075-0.0003,22.5,'24.54h')
plt.axvline(0.0398,color='k',linestyle='dashed')
plt.text(0.0398-0.0003,22.5,'25.12h')
plt.grid()
plt.title('SSH MED')
plt.legend()

# %% [markdown]
# ## tout en pyspec

# %%
dssh12UK3moispyspec = spec.Spectrum(dssh12UK3mois.copy(),dt=1)
dssh60UK3moispyspec = spec.Spectrum(dssh60UK3mois.copy(),dt=1)

dssh12NOR3moispyspec = spec.Spectrum(dssh12NOR3mois.copy(),dt=1)
dssh60NOR3moispyspec = spec.Spectrum(dssh60NOR3mois.copy(),dt=1)

dssh12IRL3moispyspec = spec.Spectrum(dssh12IRL3mois.copy(),dt=1)
dssh60IRL3moispyspec = spec.Spectrum(dssh60IRL3mois.copy(),dt=1)

dssh12MED3moispyspec = spec.Spectrum(dssh12MED3mois.copy(),dt=1)
dssh60MED3moispyspec = spec.Spectrum(dssh60MED3mois.copy(),dt=1)

# %%
fig=plt.figure(figsize=(20,20))

ax = fig.add_subplot(411)

plt.loglog(dssh12NOR3moispyspec.f,dssh12NOR3moispyspec.spec,color='b',label="NACHOS12")
plt.loglog(dssh60NOR3moispyspec.f,dssh60NOR3moispyspec.spec,color='k',label="NATL60")
plt.ylim([1e-9,20])
plt.axvline(1/12.,color='k',linestyle='dashed')
plt.text(1/12.-0.003,22,'12h')
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.003,22,'24h')
plt.grid()
plt.title('SSH NOR')
plt.legend()

ax = fig.add_subplot(412)

plt.loglog(dssh12UK3moispyspec.f,dssh12UK3moispyspec.spec,color='b',label="NACHOS12")
plt.loglog(dssh60UK3moispyspec.f,dssh60UK3moispyspec.spec,color='k',label="NATL60")
plt.ylim([1e-9,20])
plt.axvline(1/12.,color='k',linestyle='dashed')
plt.text(1/12.-0.003,22,'12h')
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.003,22,'24h')
plt.grid()
plt.title('SSH UK')
plt.legend()

ax = fig.add_subplot(413)

plt.loglog(dssh12IRL3moispyspec.f,dssh12IRL3moispyspec.spec,color='b',label="NACHOS12")
plt.loglog(dssh60IRL3moispyspec.f,dssh60IRL3moispyspec.spec,color='k',label="NATL60")
plt.ylim([1e-10,20])
plt.axvline(1/12.,color='k',linestyle='dashed')
plt.text(1/12.-0.003,22,'12h')
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.003,22,'24h')
plt.grid()
plt.title('SSH IRL')
plt.legend()

ax = fig.add_subplot(414)

plt.loglog(dssh12MED3moispyspec.f,dssh12MED3moispyspec.spec,color='b',label="NACHOS12")
plt.loglog(dssh60MED3moispyspec.f,dssh60MED3moispyspec.spec,color='k',label="NATL60")
plt.ylim([1e-11,20])
plt.axvline(1/12.,color='k',linestyle='dashed')
plt.text(1/12.-0.003,22,'12h')
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.003,22,'24h')
plt.grid()
plt.title('SSH MED')
plt.legend()

# %%
fig=plt.figure(figsize=(20,20))

ax = fig.add_subplot(411)

plt.loglog(dssh12NOR3moispyspec.f,dssh12NOR3moispyspec.spec,color='b',label="NACHOS12")
plt.loglog(dssh60NOR3moispyspec.f,dssh60NOR3moispyspec.spec,color='k',label="NATL60")
plt.ylim([1e-9,20])
plt.xlim([0.01,0.1])
plt.axvline(1/12.,color='k',linestyle='dashed')
plt.text(1/12.-0.001,22,'12h')
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.001,22,'24h')
plt.grid()
plt.title('SSH NOR')
plt.legend()

ax = fig.add_subplot(412)

plt.loglog(dssh12UK3moispyspec.f,dssh12UK3moispyspec.spec,color='b',label="NACHOS12")
plt.loglog(dssh60UK3moispyspec.f,dssh60UK3moispyspec.spec,color='k',label="NATL60")
plt.ylim([1e-9,20])
plt.xlim([0.01,0.1])
plt.axvline(1/12.,color='k',linestyle='dashed')
plt.text(1/12.-0.001,22,'12h')
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.001,22,'24h')
plt.grid()
plt.title('SSH UK')
plt.legend()

ax = fig.add_subplot(413)

plt.loglog(dssh12IRL3moispyspec.f,dssh12IRL3moispyspec.spec,color='b',label="NACHOS12")
plt.loglog(dssh60IRL3moispyspec.f,dssh60IRL3moispyspec.spec,color='k',label="NATL60")
plt.ylim([1e-10,20])
plt.xlim([0.01,0.1])
plt.axvline(1/12.,color='k',linestyle='dashed')
plt.text(1/12.-0.001,22,'12h')
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.001,22,'24h')
plt.grid()
plt.title('SSH IRL')
plt.legend()

ax = fig.add_subplot(414)

plt.loglog(dssh12MED3moispyspec.f,dssh12MED3moispyspec.spec,color='b',label="NACHOS12")
plt.loglog(dssh60MED3moispyspec.f,dssh60MED3moispyspec.spec,color='k',label="NATL60")
plt.ylim([1e-11,20])
plt.xlim([0.01,0.1])
plt.axvline(1/12.,color='k',linestyle='dashed')
plt.text(1/12.-0.001,22,'12h')
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.001,22,'24h')
plt.grid()
plt.title('SSH MED')
plt.legend()

# %%
fig=plt.figure(figsize=(20,20))

ax = fig.add_subplot(411)

plt.loglog(dssh12NOR3moispyspec.f,dssh12NOR3moispyspec.spec,color='b',label="NACHOS12")
plt.loglog(dssh60NOR3moispyspec.f,dssh60NOR3moispyspec.spec,color='k',label="NATL60")
plt.ylim([1e-9,20])
plt.xlim([0.03,0.05])
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.0001,22,'24h')
plt.axvline(0.04075,color='k',linestyle='dashed')
plt.text(0.04075-0.0003,22.5,'24.54h')
plt.axvline(0.0398,color='k',linestyle='dashed')
plt.text(0.0398-0.0003,22.5,'25.12h')
plt.grid()
plt.title('SSH NOR')
plt.legend()

ax = fig.add_subplot(412)

plt.loglog(dssh12UK3moispyspec.f,dssh12UK3moispyspec.spec,color='b',label="NACHOS12")
plt.loglog(dssh60UK3moispyspec.f,dssh60UK3moispyspec.spec,color='k',label="NATL60")
plt.ylim([1e-9,20])
plt.xlim([0.03,0.05])
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.0001,22,'24h')
plt.axvline(0.04075,color='k',linestyle='dashed')
plt.text(0.04075-0.0003,22.5,'24.54h')
plt.axvline(0.0398,color='k',linestyle='dashed')
plt.text(0.0398-0.0003,22.5,'25.12h')
plt.grid()
plt.title('SSH UK')
plt.legend()

ax = fig.add_subplot(413)

plt.loglog(dssh12IRL3moispyspec.f,dssh12IRL3moispyspec.spec,color='b',label="NACHOS12")
plt.loglog(dssh60IRL3moispyspec.f,dssh60IRL3moispyspec.spec,color='k',label="NATL60")
plt.ylim([1e-10,20])
plt.xlim([0.03,0.05])
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.0001,22,'24h')
plt.axvline(0.04075,color='k',linestyle='dashed')
plt.text(0.04075-0.0003,22.5,'24.54h')
plt.axvline(0.0398,color='k',linestyle='dashed')
plt.text(0.0398-0.0003,22.5,'25.12h')
plt.grid()
plt.title('SSH IRL')
plt.legend()

ax = fig.add_subplot(414)

plt.loglog(dssh12MED3moispyspec.f,dssh12MED3moispyspec.spec,color='b',label="NACHOS12")
plt.loglog(dssh60MED3moispyspec.f,dssh60MED3moispyspec.spec,color='k',label="NATL60")
plt.ylim([1e-11,20])
plt.xlim([0.03,0.05])
plt.axvline(1/24.,color='k',linestyle='dashed')
plt.text(1/24.-0.0001,22,'24h')
plt.axvline(0.04075,color='k',linestyle='dashed')
plt.text(0.04075-0.0003,22.5,'24.54h')
plt.axvline(0.0398,color='k',linestyle='dashed')
plt.text(0.0398-0.0003,22.5,'25.12h')
plt.grid()
plt.title('SSH MED')
plt.legend()
